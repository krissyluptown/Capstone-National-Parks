# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# %matplotlib inline

# %%
np_visits_df = pd.read_csv("../data/visits_per_year.csv")

# %%
np_visits_df.head(5)
# Out:
#       ParkName       2002       2003       2004       2005       2006  \
# 0    Acadia NP  2558572.0  2431062.0  2207847.0  2051484.0  2083588.0
# 1    Arches NP   769672.0   757781.0   733131.0   781670.0   833049.0
# 2  Badlands NP   908898.0   871034.0   936030.0   909146.0   840118.0
# 3  Big Bend NP   327747.0   312384.0   357723.0   398583.0   298717.0
# 4  Biscayne NP   513397.0   490031.0   478304.0   563728.0   608836.0
#
#         2007       2008       2009       2010  ...       2013       2014  \
# 0  2202228.0  2075857.0  2227698.0  2504208.0  ...  2254922.0  2563129.0
# 1   860181.0   928795.0   996312.0  1014405.0  ...  1082866.0  1284767.0
# 2   886654.0   845734.0   933918.0   977778.0  ...   892372.0   868094.0
# 3   364856.0   362512.0   363905.0   372330.0  ...   316953.0   314102.0
# 4   517442.0   686062.0   437745.0   467612.0  ...   486848.0   525745.0
#
#         2015       2016       2017       2018       2019     2020     2021  \
# ...

# %%
np_ranks_df = pd.read_csv("../data/annual_park_rankings.csv")

# %%
np_ranks_df.head(5)
# Out:
#                    ParkName  Rank  RecreationVisits  PercentOfTotal
# 0           Blue Ridge PKWY   1.0        15948148.0            0.05
# 1  Great Smoky Mountains NP   2.0        15948148.0            0.05
# 2           Golden Gate NRA   3.0        15948148.0            0.05
# 3               Gateway NRA   4.0        15948148.0            0.03
# 4             Lake Mead NRA   5.0        15948148.0            0.03

# %%
np_rank_and_visit_df = pd.merge(np_visits_df, np_ranks_df, how='outer', on = ['ParkName'])

# %%
np_rank_and_visit_df.head(5)
# Out:
#       ParkName       2002       2003       2004       2005       2006  \
# 0    Acadia NP  2558572.0  2431062.0  2207847.0  2051484.0  2083588.0
# 1    Arches NP   769672.0   757781.0   733131.0   781670.0   833049.0
# 2  Badlands NP   908898.0   871034.0   936030.0   909146.0   840118.0
# 3  Big Bend NP   327747.0   312384.0   357723.0   398583.0   298717.0
# 4  Biscayne NP   513397.0   490031.0   478304.0   563728.0   608836.0
#
#         2007       2008       2009       2010  ...       2016       2017  \
# 0  2202228.0  2075857.0  2227698.0  2504208.0  ...  3303393.0  3509271.0
# 1   860181.0   928795.0   996312.0  1014405.0  ...  1585718.0  1539028.0
# 2   886654.0   845734.0   933918.0   977778.0  ...   996263.0  1054325.0
# 3   364856.0   362512.0   363905.0   372330.0  ...   388290.0   440276.0
# 4   517442.0   686062.0   437745.0   467612.0  ...   514709.0   446961.0
#
#         2018       2019       2020       2021    Average   Rank  \
# ...
